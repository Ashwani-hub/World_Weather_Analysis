# %%
#Import dependencies
import pandas as pd
import numpy as np
import time
from citipy import citipy
# Import requests library
import requests
# Import API key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 782

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    time.sleep(1)
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_w_d = city_weather['weather']
        for city_w_d_desc in city_w_d:
            city_weather_desc = city_w_d_desc["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | mazamari
# Processing Record 3 of Set 1 | riyadh
# Processing Record 4 of Set 1 | dinsor
# City not found. Skipping...
# Processing Record 5 of Set 1 | saint-augustin
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | minsk mazowiecki
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | raudeberg
# Processing Record 10 of Set 1 | jaque
# Processing Record 11 of Set 1 | klaksvik
# Processing Record 12 of Set 1 | galle
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | beira
# Processing Record 15 of Set 1 | chancay
# Processing Record 16 of Set 1 | prince rupert
# Processing Record 17 of Set 1 | tavda
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | hamilton
# Processing Record 21 of Set 1 | khandyga
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | roros
# Processing Record 24 of Set 1 | avera
# Processing Record 25 of Set 1 | panjab
# Processing Record 26 of Set 1 | nabire
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | itarema
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | port moresby
# Processing Record 33 of Set 1 | maine-soroa
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | touros
# Processing Record 37 of Set 1 | codrington
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | camacha
# Processing Record 42 of Set 1 | sovetskaya
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | aswan
# Processing Record 45 of Set 1 | port augusta
# Processing Record 46 of Set 1 | saskylakh
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | vostok
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | nemuro
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | tual
# Processing Record 11 of Set 2 | gat
# Processing Record 12 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 2 | male
# Processing Record 16 of Set 2 | belmonte
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 2 | dillon
# Processing Record 20 of Set 2 | chabahar
# Processing Record 21 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 22 of Set 2 | hasaki
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | olafsvik
# Processing Record 25 of Set 2 | caohai
# Processing Record 26 of Set 2 | hongjiang
# Processing Record 27 of Set 2 | aklavik
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | rawson
# Processing Record 30 of Set 2 | berlevag
# Processing Record 31 of Set 2 | falam
# Processing Record 32 of Set 2 | lagoa
# Processing Record 33 of Set 2 | jamestown
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | beloha
# Processing Record 36 of Set 2 | manicore
# Processing Record 37 of Set 2 | hovd
# Processing Record 38 of Set 2 | arandis
# Processing Record 39 of Set 2 | kapaa
# Processing Record 40 of Set 2 | namatanai
# Processing Record 41 of Set 2 | ushuaia
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | brae
# Processing Record 45 of Set 2 | si racha
# Processing Record 46 of Set 2 | porto novo
# Processing Record 47 of Set 2 | lichinga
# Processing Record 48 of Set 2 | sharjah
# Processing Record 49 of Set 2 | iglesias
# Processing Record 50 of Set 2 | phalaborwa
# Processing Record 1 of Set 3 | cartagena del chaira
# Processing Record 2 of Set 3 | salinopolis
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | great falls
# Processing Record 5 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 3 | hibbing
# Processing Record 7 of Set 3 | husavik
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | twin falls
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | chicama
# Processing Record 12 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | mataura
# Processing Record 15 of Set 3 | qaanaaq
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | vagur
# Processing Record 18 of Set 3 | izhma
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | merauke
# Processing Record 21 of Set 3 | pahrump
# Processing Record 22 of Set 3 | beringovskiy
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | abiy adi
# City not found. Skipping...
# Processing Record 27 of Set 3 | ust-nera
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | lebu
# Processing Record 31 of Set 3 | karpathos
# Processing Record 32 of Set 3 | lapeer
# Processing Record 33 of Set 3 | saldanha
# Processing Record 34 of Set 3 | constitucion
# Processing Record 35 of Set 3 | vardo
# Processing Record 36 of Set 3 | la ronge
# Processing Record 37 of Set 3 | skjervoy
# Processing Record 38 of Set 3 | imeni babushkina
# Processing Record 39 of Set 3 | nayoro
# Processing Record 40 of Set 3 | hami
# Processing Record 41 of Set 3 | pingzhuang
# Processing Record 42 of Set 3 | chokurdakh
# Processing Record 43 of Set 3 | esperance
# Processing Record 44 of Set 3 | upernavik
# Processing Record 45 of Set 3 | iqaluit
# Processing Record 46 of Set 3 | yarke pole
# Processing Record 47 of Set 3 | sur
# Processing Record 48 of Set 3 | kyshtovka
# Processing Record 49 of Set 3 | feicheng
# Processing Record 50 of Set 3 | bredasdorp
# Processing Record 1 of Set 4 | coahuayana
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | sharlyk
# Processing Record 4 of Set 4 | castro
# Processing Record 5 of Set 4 | aykhal
# Processing Record 6 of Set 4 | fairbanks
# Processing Record 7 of Set 4 | udachnyy
# Processing Record 8 of Set 4 | saint-philippe
# Processing Record 9 of Set 4 | jerantut
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | tadine
# Processing Record 12 of Set 4 | harstad
# Processing Record 13 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 4 | tagusao
# Processing Record 15 of Set 4 | san jeronimo
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | atar
# Processing Record 18 of Set 4 | aquidauana
# Processing Record 19 of Set 4 | pangoa
# Processing Record 20 of Set 4 | bambous virieux
# Processing Record 21 of Set 4 | barcelos
# Processing Record 22 of Set 4 | arraial do cabo
# Processing Record 23 of Set 4 | jardim
# Processing Record 24 of Set 4 | bonthe
# Processing Record 25 of Set 4 | flinders
# Processing Record 26 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 4 | novoagansk
# Processing Record 28 of Set 4 | pedernales
# Processing Record 29 of Set 4 | puerto del rosario
# Processing Record 30 of Set 4 | palm beach
# Processing Record 31 of Set 4 | moiyabana
# City not found. Skipping...
# Processing Record 32 of Set 4 | kismayo
# Processing Record 33 of Set 4 | bani walid
# Processing Record 34 of Set 4 | laguna
# Processing Record 35 of Set 4 | new norfolk
# Processing Record 36 of Set 4 | srandakan
# Processing Record 37 of Set 4 | bonavista
# Processing Record 38 of Set 4 | faanui
# Processing Record 39 of Set 4 | isangel
# Processing Record 40 of Set 4 | mutsu
# Processing Record 41 of Set 4 | baoding
# Processing Record 42 of Set 4 | kaitangata
# Processing Record 43 of Set 4 | tigil
# Processing Record 44 of Set 4 | nikolskoye
# Processing Record 45 of Set 4 | aden
# Processing Record 46 of Set 4 | lebedinyy
# Processing Record 47 of Set 4 | snezhnogorsk
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | pangnirtung
# Processing Record 50 of Set 4 | rudnyy
# Processing Record 1 of Set 5 | turayf
# Processing Record 2 of Set 5 | puerto ayora
# Processing Record 3 of Set 5 | naze
# Processing Record 4 of Set 5 | waddan
# Processing Record 5 of Set 5 | san quintin
# Processing Record 6 of Set 5 | mortka
# Processing Record 7 of Set 5 | alugan
# Processing Record 8 of Set 5 | kajaani
# Processing Record 9 of Set 5 | tianpeng
# Processing Record 10 of Set 5 | ribeira grande
# Processing Record 11 of Set 5 | stokmarknes
# Processing Record 12 of Set 5 | redlands
# Processing Record 13 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 5 | jhunjhunun
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | souillac
# Processing Record 17 of Set 5 | maneadero
# Processing Record 18 of Set 5 | mahanoro
# Processing Record 19 of Set 5 | ibra
# Processing Record 20 of Set 5 | matagami
# Processing Record 21 of Set 5 | kpandu
# Processing Record 22 of Set 5 | humboldt
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 5 | victoria
# Processing Record 26 of Set 5 | lorengau
# Processing Record 27 of Set 5 | karratha
# Processing Record 28 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 5 | sao filipe
# Processing Record 30 of Set 5 | pechora
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | tuxpan
# Processing Record 33 of Set 5 | innisfail
# Processing Record 34 of Set 5 | praia da vitoria
# Processing Record 35 of Set 5 | sao joao da barra
# Processing Record 36 of Set 5 | lata
# Processing Record 37 of Set 5 | kuala terengganu
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | dicabisagan
# Processing Record 40 of Set 5 | eyl
# Processing Record 41 of Set 5 | anchorage
# Processing Record 42 of Set 5 | burshtyn
# Processing Record 43 of Set 5 | marsa matruh
# Processing Record 44 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 5 | prince albert
# Processing Record 46 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 47 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 5 | vanimo
# Processing Record 49 of Set 5 | santa rosa
# Processing Record 50 of Set 5 | dolores
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | portland
# Processing Record 3 of Set 6 | roald
# Processing Record 4 of Set 6 | dikson
# Processing Record 5 of Set 6 | rio grande
# Processing Record 6 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 6 | takoradi
# Processing Record 8 of Set 6 | chamba
# Processing Record 9 of Set 6 | guaraniacu
# Processing Record 10 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 6 | escanaba
# Processing Record 13 of Set 6 | san jose
# Processing Record 14 of Set 6 | haverfordwest
# Processing Record 15 of Set 6 | the valley
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | manutuke
# Processing Record 18 of Set 6 | machico
# Processing Record 19 of Set 6 | soyo
# Processing Record 20 of Set 6 | kirakira
# Processing Record 21 of Set 6 | hokitika
# Processing Record 22 of Set 6 | port hedland
# Processing Record 23 of Set 6 | jinchang
# Processing Record 24 of Set 6 | san policarpo
# Processing Record 25 of Set 6 | catalao
# Processing Record 26 of Set 6 | baruun-urt
# Processing Record 27 of Set 6 | fortuna
# Processing Record 28 of Set 6 | santiago del estero
# Processing Record 29 of Set 6 | kamaishi
# Processing Record 30 of Set 6 | mount isa
# Processing Record 31 of Set 6 | biloxi
# Processing Record 32 of Set 6 | asau
# Processing Record 33 of Set 6 | cockburn town
# Processing Record 34 of Set 6 | sola
# Processing Record 35 of Set 6 | santa cruz
# Processing Record 36 of Set 6 | tytuvenai
# Processing Record 37 of Set 6 | urumqi
# Processing Record 38 of Set 6 | gushikawa
# Processing Record 39 of Set 6 | pangody
# Processing Record 40 of Set 6 | fenoarivo
# Processing Record 41 of Set 6 | port macquarie
# Processing Record 42 of Set 6 | bathsheba
# Processing Record 43 of Set 6 | zenzeli
# Processing Record 44 of Set 6 | tommot
# Processing Record 45 of Set 6 | vanavara
# Processing Record 46 of Set 6 | pilar
# Processing Record 47 of Set 6 | marystown
# Processing Record 48 of Set 6 | salalah
# Processing Record 49 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 50 of Set 6 | leningradskiy
# Processing Record 1 of Set 7 | aljezur
# Processing Record 2 of Set 7 | seoul
# Processing Record 3 of Set 7 | cordoba
# Processing Record 4 of Set 7 | harper
# Processing Record 5 of Set 7 | licheng
# Processing Record 6 of Set 7 | san martin
# Processing Record 7 of Set 7 | abu samrah
# Processing Record 8 of Set 7 | aigle
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | pacific grove
# Processing Record 11 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 7 | bure
# Processing Record 13 of Set 7 | taburbah
# City not found. Skipping...
# Processing Record 14 of Set 7 | airai
# Processing Record 15 of Set 7 | pisco
# Processing Record 16 of Set 7 | sabang
# Processing Record 17 of Set 7 | alofi
# Processing Record 18 of Set 7 | teocuitatlan de corona
# Processing Record 19 of Set 7 | catamarca
# Processing Record 20 of Set 7 | ossora
# Processing Record 21 of Set 7 | muravlenko
# Processing Record 22 of Set 7 | tautira
# Processing Record 23 of Set 7 | tromso
# Processing Record 24 of Set 7 | khatanga
# Processing Record 25 of Set 7 | umm kaddadah
# Processing Record 26 of Set 7 | ahipara
# Processing Record 27 of Set 7 | hualmay
# Processing Record 28 of Set 7 | krasnoselkup
# Processing Record 29 of Set 7 | korla
# Processing Record 30 of Set 7 | road town
# Processing Record 31 of Set 7 | honiara
# Processing Record 32 of Set 7 | teahupoo
# Processing Record 33 of Set 7 | makakilo city
# Processing Record 34 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 7 | surt
# Processing Record 36 of Set 7 | tiarei
# Processing Record 37 of Set 7 | komsomolskiy
# Processing Record 38 of Set 7 | navalmoral de la mata
# Processing Record 39 of Set 7 | chanute
# Processing Record 40 of Set 7 | ola
# Processing Record 41 of Set 7 | mgandu
# Processing Record 42 of Set 7 | lebyazhye
# Processing Record 43 of Set 7 | finschhafen
# Processing Record 44 of Set 7 | thunder bay
# Processing Record 45 of Set 7 | ponta delgada
# Processing Record 46 of Set 7 | flagstaff
# Processing Record 47 of Set 7 | quang ngai
# Processing Record 48 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 7 | dingle
# Processing Record 50 of Set 7 | bingen
# Processing Record 1 of Set 8 | cozumel
# Processing Record 2 of Set 8 | mazyr
# Processing Record 3 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 8 | hofn
# Processing Record 5 of Set 8 | iroquois falls
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | shache
# Processing Record 8 of Set 8 | umm lajj
# Processing Record 9 of Set 8 | zhangye
# Processing Record 10 of Set 8 | copiapo
# Processing Record 11 of Set 8 | zhangjiakou
# Processing Record 12 of Set 8 | bengkulu
# Processing Record 13 of Set 8 | mancio lima
# Processing Record 14 of Set 8 | arica
# Processing Record 15 of Set 8 | bintulu
# Processing Record 16 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 8 | pervomayskoye
# Processing Record 18 of Set 8 | yulara
# Processing Record 19 of Set 8 | labuhan
# Processing Record 20 of Set 8 | brigantine
# Processing Record 21 of Set 8 | san andres
# Processing Record 22 of Set 8 | ambulu
# Processing Record 23 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 24 of Set 8 | tres barras
# Processing Record 25 of Set 8 | waipawa
# Processing Record 26 of Set 8 | awjilah
# Processing Record 27 of Set 8 | talnakh
# Processing Record 28 of Set 8 | belyy yar
# Processing Record 29 of Set 8 | hervey bay
# Processing Record 30 of Set 8 | jamkhed
# Processing Record 31 of Set 8 | macklin
# Processing Record 32 of Set 8 | inirida
# Processing Record 33 of Set 8 | shreveport
# Processing Record 34 of Set 8 | carnarvon
# Processing Record 35 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 8 | byron bay
# Processing Record 37 of Set 8 | chipinge
# Processing Record 38 of Set 8 | tsumeb
# Processing Record 39 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 40 of Set 8 | dunedin
# Processing Record 41 of Set 8 | baykit
# Processing Record 42 of Set 8 | cullera
# Processing Record 43 of Set 8 | lloydminster
# Processing Record 44 of Set 8 | kincardine
# Processing Record 45 of Set 8 | salinas
# Processing Record 46 of Set 8 | de aar
# Processing Record 47 of Set 8 | chake chake
# Processing Record 48 of Set 8 | padang
# Processing Record 49 of Set 8 | yeppoon
# Processing Record 50 of Set 8 | sarai alamgir
# Processing Record 1 of Set 9 | grindavik
# Processing Record 2 of Set 9 | udaipur
# Processing Record 3 of Set 9 | biharamulo
# Processing Record 4 of Set 9 | norman wells
# Processing Record 5 of Set 9 | zambezi
# Processing Record 6 of Set 9 | senador canedo
# Processing Record 7 of Set 9 | ukiah
# Processing Record 8 of Set 9 | adrar
# Processing Record 9 of Set 9 | anadyr
# Processing Record 10 of Set 9 | sikonge
# Processing Record 11 of Set 9 | bowen
# Processing Record 12 of Set 9 | christchurch
# Processing Record 13 of Set 9 | garden city
# Processing Record 14 of Set 9 | brunico
# Processing Record 15 of Set 9 | villazon
# Processing Record 16 of Set 9 | clyde river
# Processing Record 17 of Set 9 | mbandaka
# Processing Record 18 of Set 9 | kharakvasla
# Processing Record 19 of Set 9 | port blair
# Processing Record 20 of Set 9 | hortobagy
# Processing Record 21 of Set 9 | kostomuksha
# Processing Record 22 of Set 9 | westport
# Processing Record 23 of Set 9 | acari
# Processing Record 24 of Set 9 | saint anthony
# Processing Record 25 of Set 9 | vaitape
# Processing Record 26 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 27 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 28 of Set 9 | san patricio
# Processing Record 29 of Set 9 | tacuarembo
# Processing Record 30 of Set 9 | kamenka
# Processing Record 31 of Set 9 | avenal
# Processing Record 32 of Set 9 | rreshen
# Processing Record 33 of Set 9 | gizo
# Processing Record 34 of Set 9 | saint-andre-avellin
# Processing Record 35 of Set 9 | dawson creek
# Processing Record 36 of Set 9 | corn island
# Processing Record 37 of Set 9 | provideniya
# Processing Record 38 of Set 9 | asyut
# Processing Record 39 of Set 9 | aksarka
# Processing Record 40 of Set 9 | southbridge
# Processing Record 41 of Set 9 | gunjur
# Processing Record 42 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 9 | dapdap
# Processing Record 44 of Set 9 | nyurba
# Processing Record 45 of Set 9 | nhulunbuy
# Processing Record 46 of Set 9 | mabaruma
# Processing Record 47 of Set 9 | nambour
# Processing Record 48 of Set 9 | biak
# Processing Record 49 of Set 9 | jalingo
# Processing Record 50 of Set 9 | nyimba
# Processing Record 1 of Set 10 | te anau
# Processing Record 2 of Set 10 | smithers
# Processing Record 3 of Set 10 | poum
# Processing Record 4 of Set 10 | maxixe
# Processing Record 5 of Set 10 | northam
# Processing Record 6 of Set 10 | medea
# Processing Record 7 of Set 10 | axim
# Processing Record 8 of Set 10 | suluq
# Processing Record 9 of Set 10 | coihaique
# Processing Record 10 of Set 10 | duz
# City not found. Skipping...
# Processing Record 11 of Set 10 | mizdah
# Processing Record 12 of Set 10 | thompson
# Processing Record 13 of Set 10 | vohibinany
# Processing Record 14 of Set 10 | saint-pierre
# Processing Record 15 of Set 10 | boende
# Processing Record 16 of Set 10 | ostrovnoy
# Processing Record 17 of Set 10 | kaoma
# Processing Record 18 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 10 | bodaybo
# Processing Record 20 of Set 10 | robertsport
# Processing Record 21 of Set 10 | scarborough
# Processing Record 22 of Set 10 | kamiiso
# Processing Record 23 of Set 10 | emba
# Processing Record 24 of Set 10 | cururupu
# Processing Record 25 of Set 10 | kunigal
# Processing Record 26 of Set 10 | pitimbu
# Processing Record 27 of Set 10 | buala
# Processing Record 28 of Set 10 | bandundu
# Processing Record 29 of Set 10 | awbari
# Processing Record 30 of Set 10 | deputatskiy
# Processing Record 31 of Set 10 | rudnya
# Processing Record 32 of Set 10 | nosy varika
# Processing Record 33 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 34 of Set 10 | camopi
# Processing Record 35 of Set 10 | kiunga
# Processing Record 36 of Set 10 | gondanglegi
# Processing Record 37 of Set 10 | havelock
# Processing Record 38 of Set 10 | manuk mangkaw
# Processing Record 39 of Set 10 | bonfim
# Processing Record 40 of Set 10 | sydney
# Processing Record 41 of Set 10 | esso
# Processing Record 42 of Set 10 | shingu
# Processing Record 43 of Set 10 | flin flon
# Processing Record 44 of Set 10 | waterboro
# Processing Record 45 of Set 10 | haines junction
# Processing Record 46 of Set 10 | kawalu
# Processing Record 47 of Set 10 | iquitos
# Processing Record 48 of Set 10 | palmer
# Processing Record 49 of Set 10 | aripuana
# Processing Record 50 of Set 10 | angra
# City not found. Skipping...
# Processing Record 1 of Set 11 | san carlos
# Processing Record 2 of Set 11 | san cristobal
# Processing Record 3 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 11 | plavinas
# Processing Record 5 of Set 11 | borzya
# Processing Record 6 of Set 11 | luderitz
# Processing Record 7 of Set 11 | ancud
# Processing Record 8 of Set 11 | charters towers
# Processing Record 9 of Set 11 | guerrero negro
# Processing Record 10 of Set 11 | shimoda
# Processing Record 11 of Set 11 | homer
# Processing Record 12 of Set 11 | north platte
# Processing Record 13 of Set 11 | bushehr
# Processing Record 14 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 11 | kazerun
# Processing Record 16 of Set 11 | tura
# Processing Record 17 of Set 11 | betsiamites
# Processing Record 18 of Set 11 | turukhansk
# Processing Record 19 of Set 11 | limay
# Processing Record 20 of Set 11 | raga
# Processing Record 21 of Set 11 | port hawkesbury
# Processing Record 22 of Set 11 | kotka
# Processing Record 23 of Set 11 | nuuk
# Processing Record 24 of Set 11 | nikki
# Processing Record 25 of Set 11 | pajan
# Processing Record 26 of Set 11 | coos bay
# Processing Record 27 of Set 11 | cervo
# Processing Record 28 of Set 11 | srednekolymsk
# Processing Record 29 of Set 11 | jutai
# Processing Record 30 of Set 11 | bucerias
# Processing Record 31 of Set 11 | uromi
# Processing Record 32 of Set 11 | armeria
# Processing Record 33 of Set 11 | kimberley
# Processing Record 34 of Set 11 | indianola
# Processing Record 35 of Set 11 | bubaque
# Processing Record 36 of Set 11 | lakatoro
# Processing Record 37 of Set 11 | onomichi
# Processing Record 38 of Set 11 | mapimi
# Processing Record 39 of Set 11 | quesnel
# Processing Record 40 of Set 11 | sept-iles
# Processing Record 41 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 42 of Set 11 | qabis
# City not found. Skipping...
# Processing Record 43 of Set 11 | acapulco
# Processing Record 44 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 11 | vangaindrano
# Processing Record 46 of Set 11 | columbia
# Processing Record 47 of Set 11 | lima
# Processing Record 48 of Set 11 | tezu
# Processing Record 49 of Set 11 | rosario do sul
# Processing Record 50 of Set 11 | tuatapere
# Processing Record 1 of Set 12 | ambilobe
# Processing Record 2 of Set 12 | milledgeville
# Processing Record 3 of Set 12 | dudinka
# Processing Record 4 of Set 12 | mocuba
# Processing Record 5 of Set 12 | bol
# Processing Record 6 of Set 12 | college
# Processing Record 7 of Set 12 | narsaq
# Processing Record 8 of Set 12 | kijang
# Processing Record 9 of Set 12 | treinta y tres
# Processing Record 10 of Set 12 | cairns
# Processing Record 11 of Set 12 | bouca
# Processing Record 12 of Set 12 | colimes
# Processing Record 13 of Set 12 | bilma
# Processing Record 14 of Set 12 | kalmunai
# Processing Record 15 of Set 12 | sao bernardo
# Processing Record 16 of Set 12 | phangnga
# Processing Record 17 of Set 12 | bambanglipuro
# Processing Record 18 of Set 12 | havre-saint-pierre
# Processing Record 19 of Set 12 | kailua
# Processing Record 20 of Set 12 | ladario
# Processing Record 21 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 12 | areka
# Processing Record 23 of Set 12 | uberaba
# Processing Record 24 of Set 12 | san pedro
# Processing Record 25 of Set 12 | darhan
# Processing Record 26 of Set 12 | dali
# Processing Record 27 of Set 12 | santa maria
# Processing Record 28 of Set 12 | arman
# Processing Record 29 of Set 12 | orlik
# Processing Record 30 of Set 12 | anloga
# Processing Record 31 of Set 12 | khandbari
# Processing Record 32 of Set 12 | yei
# Processing Record 33 of Set 12 | guapimirim
# Processing Record 34 of Set 12 | mountain home
# Processing Record 35 of Set 12 | blagoyevo
# Processing Record 36 of Set 12 | sangar
# Processing Record 37 of Set 12 | trinidad
# Processing Record 38 of Set 12 | pangai
# Processing Record 39 of Set 12 | luanda
# Processing Record 40 of Set 12 | samarai
# Processing Record 41 of Set 12 | sungaipenuh
# Processing Record 42 of Set 12 | woodward
# Processing Record 43 of Set 12 | fallon
# Processing Record 44 of Set 12 | zhigansk
# Processing Record 45 of Set 12 | lazi
# Processing Record 46 of Set 12 | vega de alatorre
# Processing Record 47 of Set 12 | cooma
# Processing Record 48 of Set 12 | sovetskiy
# Processing Record 49 of Set 12 | manoel urbano
# Processing Record 50 of Set 12 | springfield
# Processing Record 1 of Set 13 | ketchikan
# Processing Record 2 of Set 13 | skibbereen
# Processing Record 3 of Set 13 | beian
# Processing Record 4 of Set 13 | kichera
# Processing Record 5 of Set 13 | pemba
# Processing Record 6 of Set 13 | qasigiannguit
# Processing Record 7 of Set 13 | sitka
# Processing Record 8 of Set 13 | manta
# Processing Record 9 of Set 13 | gazanjyk
# Processing Record 10 of Set 13 | half moon bay
# Processing Record 11 of Set 13 | lowicz
# Processing Record 12 of Set 13 | enid
# Processing Record 13 of Set 13 | semporna
# Processing Record 14 of Set 13 | ilhabela
# Processing Record 15 of Set 13 | chulumani
# Processing Record 16 of Set 13 | joshimath
# Processing Record 17 of Set 13 | grao mogol
# Processing Record 18 of Set 13 | lasa
# Processing Record 19 of Set 13 | ewa beach
# Processing Record 20 of Set 13 | necochea
# Processing Record 21 of Set 13 | watsa
# Processing Record 22 of Set 13 | emerald
# Processing Record 23 of Set 13 | schwarzenbach
# Processing Record 24 of Set 13 | polunochnoye
# Processing Record 25 of Set 13 | qaqortoq
# Processing Record 26 of Set 13 | puerto carreno
# Processing Record 27 of Set 13 | goderich
# Processing Record 28 of Set 13 | kapoeta
# Processing Record 29 of Set 13 | bilibino
# Processing Record 30 of Set 13 | naryan-mar
# Processing Record 31 of Set 13 | pilas
# Processing Record 32 of Set 13 | westerland
# Processing Record 33 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 34 of Set 13 | duobao
# Processing Record 35 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 13 | guanica
# Processing Record 37 of Set 13 | antonina
# Processing Record 38 of Set 13 | bollnas
# Processing Record 39 of Set 13 | waingapu
# Processing Record 40 of Set 13 | yining
# Processing Record 41 of Set 13 | gonc
# Processing Record 42 of Set 13 | vieux-habitants
# Processing Record 43 of Set 13 | sudzha
# Processing Record 44 of Set 13 | quatre cocos
# Processing Record 45 of Set 13 | spassk
# Processing Record 46 of Set 13 | yandyrka
# City not found. Skipping...
# Processing Record 47 of Set 13 | kahului
# Processing Record 48 of Set 13 | taoudenni
# Processing Record 49 of Set 13 | kloulklubed
# Processing Record 50 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 1 of Set 14 | nouadhibou
# Processing Record 2 of Set 14 | zaranj
# Processing Record 3 of Set 14 | ixtapa
# Processing Record 4 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 14 | sabzevar
# Processing Record 6 of Set 14 | rocha
# Processing Record 7 of Set 14 | veshenskaya
# Processing Record 8 of Set 14 | bajo baudo
# City not found. Skipping...
# Processing Record 9 of Set 14 | namtsy
# Processing Record 10 of Set 14 | burghausen
# Processing Record 11 of Set 14 | olinda
# Processing Record 12 of Set 14 | medyn
# Processing Record 13 of Set 14 | barreirinhas
# Processing Record 14 of Set 14 | florianopolis
# Processing Record 15 of Set 14 | ashland
# Processing Record 16 of Set 14 | sioux lookout
# Processing Record 17 of Set 14 | namibe
# Processing Record 18 of Set 14 | banda aceh
# Processing Record 19 of Set 14 | tariba
# Processing Record 20 of Set 14 | batangafo
# Processing Record 21 of Set 14 | churhat
# Processing Record 22 of Set 14 | stromness
# Processing Record 23 of Set 14 | teguldet
# Processing Record 24 of Set 14 | blagoveshchenka
# Processing Record 25 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 14 | lakes entrance
# Processing Record 27 of Set 14 | silver city
# Processing Record 28 of Set 14 | neryungri
# Processing Record 29 of Set 14 | sisimiut
# Processing Record 30 of Set 14 | madang
# Processing Record 31 of Set 14 | sao felix do xingu
# Processing Record 32 of Set 14 | pervomayskiy
# Processing Record 33 of Set 14 | taunggyi
# Processing Record 34 of Set 14 | yumen
# Processing Record 35 of Set 14 | hobyo
# Processing Record 36 of Set 14 | tateyama
# Processing Record 37 of Set 14 | sao jose da coroa grande
# Processing Record 38 of Set 14 | khani
# Processing Record 39 of Set 14 | ornskoldsvik
# Processing Record 40 of Set 14 | kariba
# Processing Record 41 of Set 14 | saryg-sep
# Processing Record 42 of Set 14 | nicoya
# Processing Record 43 of Set 14 | kindu
# Processing Record 44 of Set 14 | whitefish
# Processing Record 45 of Set 14 | mikhaylovka
# Processing Record 46 of Set 14 | meulaboh
# Processing Record 47 of Set 14 | zyryanka
# Processing Record 48 of Set 14 | sheridan
# Processing Record 49 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 14 | mananjary
# Processing Record 1 of Set 15 | batagay-alyta
# Processing Record 2 of Set 15 | kologriv
# Processing Record 3 of Set 15 | nalut
# Processing Record 4 of Set 15 | gisborne
# Processing Record 5 of Set 15 | port pirie
# Processing Record 6 of Set 15 | kununurra
# Processing Record 7 of Set 15 | muisne
# Processing Record 8 of Set 15 | henties bay
# Processing Record 9 of Set 15 | mareeba
# Processing Record 10 of Set 15 | mezen
# Processing Record 11 of Set 15 | port hardy
# Processing Record 12 of Set 15 | fuyang
# Processing Record 13 of Set 15 | pokosnoye
# Processing Record 14 of Set 15 | presidencia roque saenz pena
# Processing Record 15 of Set 15 | terrace bay
# Processing Record 16 of Set 15 | alihe
# Processing Record 17 of Set 15 | uige
# Processing Record 18 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 15 | mayo
# Processing Record 20 of Set 15 | morgan city
# Processing Record 21 of Set 15 | zhuhai
# Processing Record 22 of Set 15 | perth
# Processing Record 23 of Set 15 | petropavl
# Processing Record 24 of Set 15 | ternate
# Processing Record 25 of Set 15 | garissa
# Processing Record 26 of Set 15 | marawi
# Processing Record 27 of Set 15 | ocos
# Processing Record 28 of Set 15 | ilam
# Processing Record 29 of Set 15 | muros
# Processing Record 30 of Set 15 | peniche
# Processing Record 31 of Set 15 | springbok
# Processing Record 32 of Set 15 | paamiut
# Processing Record 33 of Set 15 | davila
# Processing Record 34 of Set 15 | aguimes
# Processing Record 35 of Set 15 | teya
# Processing Record 36 of Set 15 | manzhouli
# Processing Record 37 of Set 15 | crixas
# Processing Record 38 of Set 15 | chardara
# Processing Record 39 of Set 15 | imeni poliny osipenko
# Processing Record 40 of Set 15 | vao
# Processing Record 41 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 15 | praya
# Processing Record 43 of Set 15 | chapais
# Processing Record 44 of Set 15 | lebanon
# Processing Record 45 of Set 15 | suhbaatar
# Processing Record 46 of Set 15 | helong
# Processing Record 47 of Set 15 | feroke
# Processing Record 48 of Set 15 | madera
# Processing Record 49 of Set 15 | zhicheng
# Processing Record 50 of Set 15 | vedaranniyam
# City not found. Skipping...
# Processing Record 1 of Set 16 | london
# Processing Record 2 of Set 16 | shenjiamen
# Processing Record 3 of Set 16 | lubin
# Processing Record 4 of Set 16 | cheyenne
# Processing Record 5 of Set 16 | adre
# Processing Record 6 of Set 16 | verkh-usugli
# Processing Record 7 of Set 16 | sumbe
# Processing Record 8 of Set 16 | progreso
# Processing Record 9 of Set 16 | charneca de caparica
# Processing Record 10 of Set 16 | allende
# Processing Record 11 of Set 16 | kosh-agach
# Processing Record 12 of Set 16 | klyavlino
# Processing Record 13 of Set 16 | saint-joseph
# Processing Record 14 of Set 16 | arlit
# Processing Record 15 of Set 16 | pacasmayo
# Processing Record 16 of Set 16 | cayenne
# Processing Record 17 of Set 16 | catuday
# Processing Record 18 of Set 16 | kyrylivka
# Processing Record 19 of Set 16 | pandan
# Processing Record 20 of Set 16 | yingkou
# Processing Record 21 of Set 16 | alice springs
# Processing Record 22 of Set 16 | leiva
# Processing Record 23 of Set 16 | sao francisco de paula
# Processing Record 24 of Set 16 | ereymentau
# Processing Record 25 of Set 16 | chumphon
# Processing Record 26 of Set 16 | agadez
# Processing Record 27 of Set 16 | dawei
# Processing Record 28 of Set 16 | lawrenceburg
# Processing Record 29 of Set 16 | gombe
# Processing Record 30 of Set 16 | silvan
# Processing Record 31 of Set 16 | gidam
# Processing Record 32 of Set 16 | nome
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 719

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas -53.1500  -70.9167     37.51        87          40
# 1        Mazamari -11.3258  -74.5308     66.52        97          90
# 2          Riyadh  24.6877   46.7219     87.94        12           4
# 3  Saint-Augustin  51.2260  -58.6502     55.74        87          99
# 4          Hobart -42.8794  147.3294     54.27        61          75
#
#    Wind Speed Country Current Description
# 0       13.80      CL    scattered clouds
# 1        1.97      PE     overcast clouds
# 2        8.75      SA           clear sky
# 3        9.57      CA     overcast clouds
# 4        4.00      AU       broken clouds

# %%
#Resorting Data Frame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description" ]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     37.51        87          40
# 1        Mazamari      PE -11.3258  -74.5308     66.52        97          90
# 2          Riyadh      SA  24.6877   46.7219     87.94        12           4
# 3  Saint-Augustin      CA  51.2260  -58.6502     55.74        87          99
# 4          Hobart      AU -42.8794  147.3294     54.27        61          75
#
#    Wind Speed Current Description
# 0       13.80    scattered clouds
# 1        1.97     overcast clouds
# 2        8.75           clear sky
# 3        9.57     overcast clouds
# 4        4.00       broken clouds

# %%
#Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export the City_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
